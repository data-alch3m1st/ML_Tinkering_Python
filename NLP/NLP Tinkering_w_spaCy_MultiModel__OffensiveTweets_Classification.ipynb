# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import spacy

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC

from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    classification_report, accuracy_score
    , confusion_matrix, ConfusionMatrixDisplay
)

import warnings
warnings.simplefilter('ignore')

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
# If not installed already, install the spaCy large model and the 
# !python -m spacy download en_core_web_trf 
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-trf==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.8.0/en_core_web_trf-3.8.0-py3-none-any.whl (457.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 2.5 MB/s eta 0:00:0000:0100:01
# Collecting spacy-curated-transformers<1.0.0,>=0.2.2 (from en-core-web-trf==3.8.0)
#   Obtaining dependency information for spacy-curated-transformers<1.0.0,>=0.2.2 from https://files.pythonhosted.org/packages/42/d8/f053d43125ae4ad14f3e2a12a475a656128233f1f40a272c6e09a05c73e8/spacy_curated_transformers-0.3.1-py2.py3-none-any.whl.metadata
#   Downloading spacy_curated_transformers-0.3.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting curated-transformers<0.2.0,>=0.1.0 (from spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0)
#   Obtaining dependency information for curated-transformers<0.2.0,>=0.1.0 from https://files.pythonhosted.org/packages/d6/67/3b72b3fdfcadab61bc8f59c17e63770e526ffabd583ed32f174a7c01af85/curated_transformers-0.1.1-py2.py3-none-any.whl.metadata
#   Downloading curated_transformers-0.1.1-py2.py3-none-any.whl.metadata (965 bytes)
# Collecting curated-tokenizers<0.1.0,>=0.0.9 (from spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0)
#   Obtaining dependency information for curated-tokenizers<0.1.0,>=0.0.9 from https://files.pythonhosted.org/packages/1f/f2/e4fa27a078ca6d7db87f82124695ce8822104285d4f8b3ec9900ab18c2df/curated_tokenizers-0.0.9-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading curated_tokenizers-0.0.9-cp311-cp311-macosx_10_9_x86_64.whl.metadata (1.9 kB)
# Requirement already satisfied: torch>=1.12.0 in /Users/t4ng0_br4v0/anaconda3/lib/python3.11/site-packages (from spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2.2.2)
# Requirement already satisfied: regex>=2022 in /Users/t4ng0_br4v0/anaconda3/lib/python3.11/site-packages (from curated-tokenizers<0.1.0,>=0.0.9->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2022.7.9)
# Requirement already satisfied: filelock in /Users/t4ng0_br4v0/anaconda3/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/t4ng0_br4v0/anaconda3/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (4.14.0)
# Requirement already satisfied: sympy in /Users/t4ng0_br4v0/anaconda3/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (1.11.1)
# Requirement already satisfied: networkx in /Users/t4ng0_br4v0/anaconda3/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.1)
# Requirement already satisfied: jinja2 in /Users/t4ng0_br4v0/anaconda3/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.1.2)
# Requirement already satisfied: fsspec in /Users/t4ng0_br4v0/anaconda3/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2023.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/t4ng0_br4v0/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/t4ng0_br4v0/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (1.3.0)
# Downloading spacy_curated_transformers-0.3.1-py2.py3-none-any.whl (237 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.9/237.9 kB 952.3 kB/s eta 0:00:00a 0:00:01
# Downloading curated_tokenizers-0.0.9-cp311-cp311-macosx_10_9_x86_64.whl (733 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 733.6/733.6 kB 4.6 MB/s eta 0:00:0000:0100:01
# Downloading curated_transformers-0.1.1-py2.py3-none-any.whl (25 kB)
# Installing collected packages: curated-tokenizers, curated-transformers, spacy-curated-transformers, en-core-web-trf
# Successfully installed curated-tokenizers-0.0.9 curated-transformers-0.1.1 en-core-web-trf-3.8.0 spacy-curated-transformers-0.3.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')

# %%
# Load SpaCy model

nlp = spacy.load("en_core_web_lg")

# %%
# Custom tokenizer using SpaCy
def spacy_tokenizer(text):
    doc = nlp(text)
    return [token.lemma_ for token in doc if not token.is_stop and not token.is_punct]

# %%
# Load the dataset from Hugging Face:
df = pd.read_parquet("hf://datasets/tdavidson/hate_speech_offensive/data/train-00000-of-00001.parquet")

df.shape
df.head()
df.info()
# Out:
# (24783, 6)
#    count  hate_speech_count  offensive_language_count  neither_count  class  \
# 0      3                  0                         0              3      2
# 1      3                  0                         3              0      1
# 2      3                  0                         3              0      1
# 3      3                  0                         2              1      1
# 4      6                  0                         6              0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   count                     24783 non-null  int64
#  1   hate_speech_count         24783 non-null  int64
#  2   offensive_language_count  24783 non-null  int64
#  3   neither_count             24783 non-null  int64
#  4   class                     24783 non-null  int64
#  5   tweet                     24783 non-null  object
# dtypes: int64(5), object(1)
# memory usage: 1.1+ MB

# %%
df['class'].value_counts()
# Out:
# class
# 1    19190
# 2     4163
# 0     1430
# Name: count, dtype: int64

# %%
# Encode labels:
# 0: 'hate-speech', 1: 'offensive-language' or 2: 'neither'

df['label_actual'] = df['class'].map({0: 'hate-speech', 1: 'offensive-language', 2: 'neither' })

# %%
# Visualize label distribution
sns.countplot(
    x='class', data=df, hue='label_actual'
)
plt.title("Label Distribution")
plt.show();

# %%
df.head(1)
# Out:
#    count  hate_speech_count  offensive_language_count  neither_count  class  \
# 0      3                  0                         0              3      2
#
#                                                tweet label_actual
# 0  !!! RT @mayasolovely: As a woman you shouldn't...      neither

# %%
X = df['tweet']
y = df['class']

X.shape, y.shape
# Out:
# ((24783,), (24783,))

# %%
# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2
    , random_state=27, stratify=y
)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((19826,), (4957,), (19826,), (4957,))

# %%
# Vectorize text data using TfidfVectorizer (* with spaCy_tokenizer;)
tfidf = TfidfVectorizer(
    tokenizer=spacy_tokenizer, lowercase=True
#     , stop_words='english' # adding in the english stopwords w/ spaCy tokenizer; might break the model,,,
)

X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
X_train_tfidf.shape, X_test_tfidf.shape

X_train_tfidf
# Out:
# ((19826, 31658), (4957, 31658))
# <19826x31658 sparse matrix of type '<class 'numpy.float64'>'
# 	with 159998 stored elements in Compressed Sparse Row format>

# %%
# # Select a base model (e.g., MultinomialNB) for hyperparameter tuning
# base_model = MultinomialNB()

# Initialize models for comparison
models = {
    'MultinomialNB': MultinomialNB(),
    'LogisticRegression': LogisticRegression(
        max_iter=1000, random_state=27
    ),
    'SVC': SVC(random_state=27),
    'LinearSVC': LinearSVC(
        max_iter=1000, random_state=27
    )
}

# %%
# Evaluate models
for name, model in models.items():
    
    model.fit(X_train_tfidf, y_train)
    
    y_pred = model.predict(X_test_tfidf)
    
    accuracy = accuracy_score(y_test, y_pred)
    
    print(f"{name} Accuracy: {accuracy:.4f}")
# Out:
# MultinomialNB()
# MultinomialNB Accuracy: 0.7912
# LogisticRegression(max_iter=1000, random_state=27)
# LogisticRegression Accuracy: 0.8913
# SVC(random_state=27)
# SVC Accuracy: 0.8961
# LinearSVC(random_state=27)
# LinearSVC Accuracy: 0.8919

# %%
# Since SVC gave us the higest accuracy - use SVC as our 'base model'
base_model = SVC(random_state=27)

# %%
# %%time
# Out:
# UsageError: %%time is a cell magic, but the cell body is empty. Did you mean the line magic %time (single %)?

# %%
# Define the parameter grid for GridSearchCV (using our 'base_model' above), with algo-specific hyperparams!

param_grid = {
    'C': np.logspace(-3, 2, 16)
    , 'kernel': ['rbf'] # ['linear', 'rbf', 'poly'] - all are available but rbf is usually way to go;
    , 'gamma': ['auto'] # ['scale', 'auto']
  #  , 'degree': [2, 3, 4]  # Only relevant for 'poly' kernel
}

# Initialize the GridSearchCV object
grid_search = GridSearchCV(
    estimator=base_model
    , param_grid=param_grid
    , scoring='accuracy'
    , cv=5
    , n_jobs=-1 # Runs on all cpu's
)
# Out:
# UsageError: Line magic function `%%time` not found.

# %%
# Fit that ish!

grid_search.fit(X_train_tfidf, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(random_state=27), n_jobs=-1,
#              param_grid={'C': array([1.00000000e-03, 2.15443469e-03, 4.64158883e-03, 1.00000000e-02,
#        2.15443469e-02, 4.64158883e-02, 1.00000000e-01, 2.15443469e-01,
#        4.64158883e-01, 1.00000000e+00, 2.15443469e+00, 4.64158883e+00,
#        1.00000000e+01, 2.15443469e+01, 4.64158883e+01, 1.00000000e+02]),
#                          'gamma': ['auto'], 'kernel': ['rbf']},
#              scoring='accuracy')

# %%
# Print best hyperparameters and best score
print("Best Parameters:", grid_search.best_params_)
print("Best Cross-Validation Accuracy:", grid_search.best_score_)
# Out:
# Best Parameters: {'C': 0.001, 'gamma': 'auto', 'kernel': 'rbf'}
# Best Cross-Validation Accuracy: 0.7743367297946798

# %%
# Evaluate best model on test data
best_model = grid_search.best_estimator_

# Now FIT the best_model (MUST DO BEFORE PREDICTING!!! {otherwise, you essentially reset the model! :o })
best_model.fit(X_train_tfidf, y_train)
# Out:
# SVC(C=0.001, gamma='auto', random_state=27)

# %%
y_test_pred = best_model.predict(X_test_tfidf)

print("Test Accuracy:", accuracy_score(y_test, y_test_pred))
confusion_matrix(y_test, y_test_pred)
print(classification_report(y_test, y_test_pred))
# Out:
# Test Accuracy: 0.7742586241678434
# array([[   0,  286,    0],
#        [   0, 3838,    0],
#        [   0,  833,    0]])
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       286
#            1       0.77      1.00      0.87      3838
#            2       0.00      0.00      0.00       833
#
#     accuracy                           0.77      4957
#    macro avg       0.26      0.33      0.29      4957
# weighted avg       0.60      0.77      0.68      4957

# %%
ConfusionMatrixDisplay.from_estimator(
    best_model, X_test_tfidf, y_test
    , cmap='Blues'
);

# %%
# Build a pipeline for testing on sample strings
pipeline = Pipeline([
    ("tfidf", TfidfVectorizer(
        tokenizer=spacy_tokenizer
        , lowercase=True
        , stop_words='english'
    ))
    , ('model', best_model)
])

# %%
# HAVE TO FIT THE PIPES!!!
# Since the model is already trained, can fit directly to X, y;

pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(stop_words='english',
#                                  tokenizer=<function spacy_tokenizer at 0x17778b920>)),
#                 ('model', SVC(C=0.001, gamma='auto', random_state=27))])

# %%
df.head(1)
# Out:
#    count  hate_speech_count  offensive_language_count  neither_count  class  \
# 0      3                  0                         0              3      2
#
#                                                tweet label_actual
# 0  !!! RT @mayasolovely: As a woman you shouldn't...      neither

# %%
# Test pipeline on sample strings
sample_strings = [
    "You suck and I hate your stupid face!",
    "HFuckity fuck fucker fuckeroni",
    "Yo my dude foshizzlecoin is off the sheezy mothafucka",
    "Bitcoin is going to the moooooooon!",
    "Enlarge your portfolio 1000% with my proven investment secrets!",
    "@bizzle, whassup muh thugg",
    "This airline sucks!",
    "The thugg-lyfe chose ME"
]

# %%
predictions = pipeline.predict(sample_strings)

# Display predictions mapping
label_mapping = {0: 'hate-speech', 1: 'offensive-language', 2: 'neither'}

for text, label in zip(sample_strings, predictions):
    # Use the label to get the corresponding prediction
    prediction_text = label_mapping.get(label, 'unknown')
    print(f"Message: {text} -> Prediction: {prediction_text}\n")
# Out:
# Message: You suck and I hate your stupid face! -> Prediction: offensive-language
#
# Message: HFuckity fuck fucker fuckeroni -> Prediction: offensive-language
#
# Message: Yo my dude foshizzlecoin is off the sheezy mothafucka -> Prediction: offensive-language
#
# Message: Bitcoin is going to the moooooooon! -> Prediction: offensive-language
#
# Message: Enlarge your portfolio 1000% with my proven investment secrets! -> Prediction: offensive-language
#
# Message: @bizzle, whassup muh thugg -> Prediction: offensive-language
#
# Message: This airline sucks! -> Prediction: neither
#
# Message: The thugg-lyfe chose ME -> Prediction: neither

# %%
X_test_tfidf.shape
# Out:
# (4957, 31621)

# %%
base_model
# Out:
# MultinomialNB()

# %%
best_model
# Out:
# MultinomialNB(alpha=0.1)
